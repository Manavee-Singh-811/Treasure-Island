# %% [markdown]
# # Treasure Island

# %%
print("Welcome to Treasure Island. Let's Find the Treasure\n")

print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/[Manavee]
*******************************************************************************
''')


step1=input("Would you like to go left/right?(Type left/right)\n").strip().lower()
if step1=="left":
    step2= input("\nYou have reached a lake, would you like to swim or wait for a boat?(Type swim/wait)\n").strip().lower()           
    if step2=="wait":
        step3=input("\nThe boat dropped you off in front of three doors.Which door would you like to enter? (Type red/blue/yellow)\n").strip().lower()
        if step3=="yellow":
            print("\nCongratulations you have reached the treasure!!!")
        elif step3=="red":
            print("\nU have reached the room of fire. Game Over")
        elif step3== "blue":
            print("\nU have reached the end of earth. Game Over ")
        else:
            print("\nWait there is no such door. Game Over")
    else:
        print("U have been attacked by crocodiles. Game Over")
else:
    print("U have reached a monstor's cave.Game Over")
# Out:
# Welcome to Treasure Island. Let's Find the Treasure
#
#
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# ...
